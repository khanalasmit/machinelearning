# %% [markdown]
# ## **BIAS VARIENCE AND RANDOM FOREST**

# %% [markdown]
# * It converts model into low varience and low bias model. It reduces the varience while maintaing low bias thus making the model as **so**.

# %% [markdown]
# Here each model is trained on sample datasets thus reducing the varience using the muliptle decision tree as base models.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
np.random.seed(10)
X,y=make_circles(n_samples=500,factor=0.1,noise=0.35,random_state=42)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X.shape
# Out:
# (500, 2)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.legend(y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier(random_state=42)
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
x_range=np.linspace(X.min(),X.max(),100)
xx1,xx2=np.meshgrid(x_range,x_range)
y_hat=dtree.predict(np.c_[xx1.ravel(),xx2.ravel()])
y_hat=y_hat.reshape(xx1.shape)
plt.contourf(xx1,xx2,y_hat,alpha=0.2)
plt.scatter(X[:,0],X[:,1],c=y,cmap='BuPu',alpha=0.7)
plt.title('Decision tree')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=500,random_state=42)
rf.fit(X_train,y_train)
plt.figure(figsize=(12,8))
x_range=np.linspace(X.min(),X.max(),100)
xx1,xx2=np.meshgrid(x_range,x_range)
y_hat=rf.predict(np.c_[xx1.ravel(),xx2.ravel()])
y_hat=y_hat.reshape(xx1.shape)
plt.contourf(xx1,xx2,y_hat,alpha=0.2)
plt.scatter(X[:,0],X[:,1],c=y,cmap='Oranges',alpha=0.7)
plt.title('Random forest')
plt.show()
