# %% [markdown]
# <p><b>Worked with the csv file using the pandas and also fetched the csv from web</b></p>

# %%
import pandas as pd
df=pd.read_csv('advertising.csv')

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [markdown]
# <ul>
#     <li style='color:DARK; font-size:20px;'><b>USING THE REQUEST LIBRARY FOR THE CSV FILE</b></li>
# </ul>

# %%
import pandas as pd
import requests
from io import StringIO

url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'}

req = requests.get(url, headers=headers)
data = StringIO(req.text)
df = pd.read_csv(data)
print(df.head())  # Verify the output
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING THE INDEX-COL PARAMETER</b></li>
# </ul>

# %%
print(pd.read_csv('advertising.csv',index_col='Age'))
# Out:
#      Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# Age
# 35                      68.95     61833.90                256.09
# 31                      80.23     68441.85                193.77
# 26                      69.47     59785.94                236.50
# 29                      74.15     54806.18                245.89
# 35                      68.37     73889.99                225.58
# ..                        ...          ...                   ...
# 30                      72.97     71384.57                208.58
# 45                      51.30     67782.17                134.42
# 51                      51.63     42415.72                120.37
# 19                      55.55     41920.79                187.95
# 26                      45.01     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# Age
# 35      Cloned 5thgeneration orchestration     Wrightburgh     0
# ...

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING "headers" PARAMETER</b></li>
# </ul>

# %%
pd.read_csv('advertising.csv',header=0)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING "use_cols" PARAMETER</b></li>
# </ul>

# %%
pd.read_csv('advertising.csv',usecols=['Daily Time Spent on Site',
                                       'Age',
                                       'Area Income'])
# Out:
#      Daily Time Spent on Site  Age  Area Income
# 0                       68.95   35     61833.90
# 1                       80.23   31     68441.85
# 2                       69.47   26     59785.94
# 3                       74.15   29     54806.18
# 4                       68.37   35     73889.99
# ..                        ...  ...          ...
# 995                     72.97   30     71384.57
# 996                     51.30   45     67782.17
# 997                     51.63   51     42415.72
# 998                     55.55   19     41920.79
# 999                     45.01   26     29875.80
#
# [1000 rows x 3 columns]

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING "Skiprows/nrows" PARAMETER</b></li>
# </ul>

# %%
pd.read_csv('advertising.csv',skiprows=[4])
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       68.37   35     73889.99                225.58
# 4                       59.99   23     59761.56                226.74
# ..                        ...  ...          ...                   ...
# 994                     72.97   30     71384.57                208.58
# 995                     51.30   45     67782.17                134.42
# 996                     51.63   51     42415.72                120.37
# 997                     55.55   19     41920.79                187.95
# 998                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# ...

# %%
pd.read_csv('advertising.csv',nrows=100)
# Out:
#     Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                      68.95   35     61833.90                256.09
# 1                      80.23   31     68441.85                193.77
# 2                      69.47   26     59785.94                236.50
# 3                      74.15   29     54806.18                245.89
# 4                      68.37   35     73889.99                225.58
# ..                       ...  ...          ...                   ...
# 95                     72.84   26     52968.22                238.63
# 96                     45.72   36     22473.08                154.02
# 97                     39.94   41     64927.19                156.30
# 98                     35.61   46     51868.85                158.22
# 99                     79.71   34     69456.83                211.65
#
#                             Ad Topic Line             City  Male     Country  \
# ...

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING "encoding" PARAMETER</b></li>
# </ul>

# %%
#use when we do not have utf encoding in the csv file then put the same encoding parameter in the encoding you get when you run a code.
#pd.read_csv('   ',encoding='latin-1')

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING"on bad lines" PARAMETER</b></li>
# </ul>

# %%
pd.read_csv('advertising.csv', on_bad_lines='skip')
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>USING "dtypes" PARAMETER</b></li>
# </ul>

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>HANDELLING DATES</b></li>
# </ul>

# %%
df=pd.read_csv('advertising.csv',parse_dates=['Timestamp']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 78.3+ KB

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>CONVERTORS</b></li>
# </ul>

# %%
'''def rename(name):
    if name=='royal challengers banglore'
        return 'RCB'
pd.read_csv('....',converters={'team1':rename})'''
# Out:
# "def rename(name):\n    if name=='royal challengers banglore'\n    return 'RCB'\npd.read_csv('....',converters={'team1':rename})"

# %% [markdown]
# <ul>
# <li style='font-size:20px'><b>na_values PARAMETER</b></li>
# </ul>

# %%
#pd.read_csv('advertising.csv',na_values=['Male'],'any other values')
