# %% [markdown]
# ### **DEPTH OF TREE**

# %% [markdown]
# - taking the max depth very low will cause the underfittng.
# - taking the max depth to the point where we extract all the leaf nodes will cause the overfitting.

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

# %%
def analyzer(max_depth):
    iris=load_iris()
    X=iris.data
    y=iris.target
    X=X[:,[0,2]]  
    clf=DecisionTreeClassifier(max_depth=max_depth)
    clf.fit(X,y)
    a=np.arange(start=X[:,0].min()-5,stop=X[:,0].max()+5,step=0.1)
    b=np.arange(start=X[:,1].min()-2,stop=X[:,1].max()+2,step=0.1)
    XX,YY=np.meshgrid(a,b)
    input_array=np.array([XX.ravel(),YY.ravel()]).T
    labels=clf.predict(input_array)
    plt.contourf(XX,YY,labels.reshape(XX.shape),alpha=0.5)
    plt.scatter(X[:,0],X[:,1],c=y)
    plt.title(f"for depth ={max_depth}")
    plt.show()

# %%
analyzer(max_depth=None)

# %%
for i in range(1,6):
    analyzer(max_depth=int(i))

# %% [markdown]
# ### **SOME IMPORTANT PARAMETERS**

# %% [markdown]
# ### *CRITERION*

# %% [markdown]
# **gini**:better\
# **entropy**:similar but less prefered

# %% [markdown]
# ### *Splitter*

# %% [markdown]
# *random*:reduces the overfitting\
# *best:* chance of overfitting

# %% [markdown]
# ### *MIN SAMPLES*

# %% [markdown]
# Stops if the min samples in the node of the tree is less than that.

# %% [markdown]
# ### *Max FEATURES*

# %% [markdown]
# Max features that Decision nodes will use to split. but features are selected randomly
