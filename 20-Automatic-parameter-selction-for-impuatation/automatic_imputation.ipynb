# %% [markdown]
# ### **Automatically select imputer parameters**

# %% [markdown]
# It uses grid search for the automatic imputation.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer

from sklearn.model_selection import train_test_split,GridSearchCV

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic=titanic[['sex','age','fare','embarked','survived']]

# %%
X=titanic.drop(columns=['survived'])
Y=titanic['survived']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
numerical_features=['age','fare']
categorical_features=['sex','embarked']
numerical_transformer=Pipeline(steps=[
    ('imputer1',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])
categorical_transformer=Pipeline(steps=[
    ('imputer2',SimpleImputer(strategy='most_frequent')),
    ('one_hot_encoder',OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('num',numerical_transformer,numerical_features),
        ('cat',categorical_transformer,categorical_features)
    ]
    
)

# %%
clf=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('classifier',LogisticRegression())
])

# %%
from sklearn import set_config
set_config(display='diagram')
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer1',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer2',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one_hot_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['sex', 'embarked'])])),
#                 ('classifier', LogisticRegression())])

# %%
param_grid = {
    'preprocessor__num__imputer1__strategy': ['mean', 'median'],
    'preprocessor__cat__imputer2__strategy': ['most_frequent', 'constant'],
    'classifier__C': [0.1, 1.0, 10, 100]
}

# %%
grid_search=GridSearchCV(clf,param_grid,cv=10)

# %%
grid_search.fit(X_train,Y_train)
print(f"Best Params:",grid_search.best_params_)
# Out:
# Best Params: {'classifier__C': 1.0, 'preprocessor__cat__imputer2__strategy': 'most_frequent', 'preprocessor__num__imputer1__strategy': 'mean'}

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results = cv_results.sort_values("mean_test_score", ascending=False)

# %%
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        0.009318      0.005865         0.002314        0.002669
# 6        0.007126      0.007386         0.004707        0.007191
# 5        0.006721      0.007007         0.005404        0.006786
# 4        0.005097      0.003044         0.003965        0.004153
# 11       0.006763      0.007169         0.003163        0.006107
# 10       0.008790      0.008423         0.001507        0.004522
# 9        0.005480      0.008077         0.005537        0.005871
# 8        0.006846      0.002547         0.003914        0.004435
# 12       0.007258      0.005644         0.002121        0.003241
# 13       0.008074      0.006304         0.002893        0.004995
# 14       0.007037      0.007733         0.004076        0.006199
# 15       0.007102      0.006992         0.001665        0.004676
# 0        0.008414      0.002189         0.001582        0.002179
# 1        0.005186      0.005715         0.003656        0.005927
# 2        0.007233      0.004779         0.004421        0.004029
# 3        0.007008      0.000569         0.003311        0.000515
#
#     param_classifier__C param_preprocessor__cat__imputer2__strategy  \
# 7                   1.0                                    constant
# 6                   1.0                                    constant
# 5                   1.0                               most_frequent
# 4                   1.0                               most_frequent
# 11                 10.0                                    constant
# 10                 10.0                                    constant
# 9                  10.0                               most_frequent
# 8                  10.0                               most_frequent
# 12                100.0                               most_frequent
# 13                100.0                               most_frequent
# 14                100.0                                    constant
# 15                100.0                                    constant
# 0                   0.1                               most_frequent
# 1                   0.1                               most_frequent
# 2                   0.1                                    constant
# 3                   0.1                                    constant
#
#    param_preprocessor__num__imputer1__strategy  \
# 7                                       median
# 6                                         mean
# 5                                       median
# 4                                         mean
# 11                                      median
# 10                                        mean
# 9                                       median
# 8                                         mean
# 12                                        mean
# 13                                      median
# 14                                        mean
# 15                                      median
# 0                                         mean
# 1                                       median
# 2                                         mean
# 3                                       median
#
#                                                params  split0_test_score  \
# 7   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667
# 6   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667
# 5   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667
# 4   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667
# 11  {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667
# 10  {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667
# 9   {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667
# 8   {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667
# 12  {'classifier__C': 100, 'preprocessor__cat__imp...           0.791667
# 13  {'classifier__C': 100, 'preprocessor__cat__imp...           0.791667
# 14  {'classifier__C': 100, 'preprocessor__cat__imp...           0.791667
# 15  {'classifier__C': 100, 'preprocessor__cat__imp...           0.791667
# 0   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667
# 1   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667
# 2   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667
# 3   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 7            0.708333  ...           0.816901           0.802817
# 6            0.708333  ...           0.816901           0.802817
# 5            0.708333  ...           0.816901           0.802817
# 4            0.708333  ...           0.816901           0.802817
# 11           0.708333  ...           0.816901           0.802817
# 10           0.708333  ...           0.816901           0.802817
# 9            0.708333  ...           0.816901           0.802817
# 8            0.708333  ...           0.816901           0.802817
# 12           0.708333  ...           0.816901           0.802817
# 13           0.708333  ...           0.816901           0.802817
# 14           0.708333  ...           0.816901           0.802817
# 15           0.708333  ...           0.816901           0.802817
# 0            0.708333  ...           0.816901           0.802817
# 1            0.708333  ...           0.816901           0.802817
# 2            0.708333  ...           0.816901           0.802817
# 3            0.708333  ...           0.816901           0.802817
#
#     split5_test_score  split6_test_score  split7_test_score  \
# 7             0.71831           0.732394           0.788732
# 6             0.71831           0.732394           0.788732
# 5             0.71831           0.732394           0.788732
# 4             0.71831           0.732394           0.788732
# 11            0.71831           0.732394           0.788732
# 10            0.71831           0.732394           0.788732
# 9             0.71831           0.732394           0.788732
# 8             0.71831           0.732394           0.788732
# 12            0.71831           0.732394           0.788732
# 13            0.71831           0.732394           0.788732
# 14            0.71831           0.732394           0.788732
# 15            0.71831           0.732394           0.788732
# 0             0.71831           0.732394           0.788732
# 1             0.71831           0.732394           0.788732
# 2             0.71831           0.732394           0.788732
# 3             0.71831           0.732394           0.788732
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 7            0.802817           0.788732         0.773944        0.036891
# 6            0.802817           0.788732         0.773944        0.036891
# 5            0.802817           0.788732         0.773944        0.036891
# 4            0.802817           0.788732         0.773944        0.036891
# 11           0.802817           0.788732         0.773944        0.036891
# 10           0.802817           0.788732         0.773944        0.036891
# 9            0.802817           0.788732         0.773944        0.036891
# 8            0.802817           0.788732         0.773944        0.036891
# 12           0.802817           0.788732         0.773944        0.036891
# 13           0.802817           0.788732         0.773944        0.036891
# 14           0.802817           0.788732         0.773944        0.036891
# 15           0.802817           0.788732         0.773944        0.036891
# 0            0.802817           0.774648         0.772535        0.036566
# 1            0.802817           0.774648         0.772535        0.036566
# 2            0.802817           0.774648         0.772535        0.036566
# 3            0.802817           0.774648         0.772535        0.036566
#
#     rank_test_score
# 7                 1
# 6                 1
# 5                 1
# 4                 1
# 11                1
# 10                1
# 9                 1
# 8                 1
# 12                1
# 13                1
# 14                1
# 15                1
# 0                13
# 1                13
# 2                13
# 3                13
#
# [16 rows x 21 columns]
